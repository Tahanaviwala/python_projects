# %% [markdown]
# # Assignment 7
#
# Name:

# %% [markdown]
# ## Setup
#
# The following code imports the required libraries and loads the ```grades.csv``` file into a Pandas DataFrame.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
def normal_distribution(x, mu, sigma):
    return 1/(sigma * np.sqrt(2*np.pi)) * np.exp(-(x-mu)**2/(2*sigma**2))

# %%
df = pd.read_csv('grades.csv')
df.shape
# Out:
# (100, 5)

# %%
Data = np.array(df['Final Grade'])
Data = np.sort(Data, axis=0)

binSize = 5
bins    = []
for i in range(int(len(Data)/binSize)+1):
    bins.append(i*binSize)

count = []

for i in range(len(bins)-1):
    x = 0
    for j in range(len(Data)):
        if (Data[j] > bins[i] and Data[j] <= bins[i+1] ):
            x= x+1
    count.append(x)
    
count = np.array(count)

# %matplotlib inline
# %matplotlib inline
count = normal_distribution(count, count.mean(), count.var())
plt.hist(count)
plt.show()

# %%
plt.plot(normal_distribution(Data, Data.mean(), Data.var()))

# %% [markdown]
# ## Density of the final grades
#
# Make a plot that meets the following criteria:
# * normalized histogram with 20 bins in the range 0 to 100 using the Final Grade column
# * a line plot of the normal distribution using the mean and standard deviation of the final grades
# * appropriate labels on the both the x and y axes
# * appropriate title
# * appropriate legend

# %% [markdown]
# ## Bar chart of final letter grades
#
# Make a plot the meets the following criteria:
# * horizontal bar chart of the final letter grades
# * ten evenly spaced tick marks on the x axis from 0 to the maximum mean price
# * appropriate labels on the x and y axes
# * appropriate title
#
# The letter grade scale is as follows:
# * A: 90 - 100
# * B: 80 - 89
# * C: 70 - 79
# * D: 60 - 69
# * F: 0 - 59

# %%
score = [0.0, 60.0, 70.0, 80.0, 90.0, 100.0]
grades = {'A':0, 'B':0, 'C':0, 'D':0,  'F':0}


for j in range(len(Data)):
    if (Data[j] >= 90 and Data[j] < 100 ):
            grades['A']  +=1
    elif(Data[j] >= 80 and Data[j] < 90 ):        
            grades['B']  +=1
    elif(Data[j] >= 70 and Data[j] < 80 ):        
            grades['C']  +=1
    elif(Data[j] >= 60 and Data[j] < 70 ):        
            grades['D']  +=1
    else:      
            grades['F']  +=1

    
# grades {'A': 6, 'B': 23, 'C': 21, 'D': 21, 'F': 29}  results in dictionary

y_pos = np.arange(len(grades.keys()))
plt.barh(y_pos, grades.values(), align='center')
plt.yticks(y_pos, grades.values())
plt.xlabel('No of Students')
plt.title('Lette Grade')
plt.show()

# %%
grades  = dict(sorted(grades.items(), key=lambda x: x[1] , reverse = True))

fig = plt.figure()
ax = fig.add_subplot(111)
ax.barh(list(grades.keys()), list(grades.values()), align='center', height=0.5, color='b')
ax.set_yticks(list(grades.keys()))
ax.set_xlabel('Number of students')
ax.set_ylabel('Letter Grades')

ax.set_title('Letter Grades Count')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Data
# Out:
# array([41.53, 48.13, 48.93, 49.  , 49.07, 49.47, 49.53, 49.73, 49.73,
#        49.87, 50.07, 50.33, 50.87, 51.  , 51.33, 51.67, 51.93, 52.47,
#        52.53, 52.93, 53.6 , 54.27, 58.27, 59.  , 59.2 , 59.53, 59.67,
#        59.73, 59.93, 60.67, 60.67, 60.8 , 61.53, 62.73, 62.87, 63.6 ,
#        64.2 , 64.47, 64.6 , 65.07, 65.93, 67.33, 67.93, 68.33, 69.  ,
#        69.07, 69.2 , 69.2 , 69.33, 69.8 , 70.4 , 70.6 , 70.73, 70.93,
#        71.13, 72.2 , 72.33, 73.87, 75.8 , 76.  , 77.13, 77.93, 78.07,
#        78.07, 78.4 , 78.53, 78.8 , 79.13, 79.47, 79.47, 79.6 , 80.07,
#        80.73, 80.87, 81.07, 81.93, 82.8 , 82.93, 83.07, 84.47, 84.67,
#        85.2 , 85.27, 85.47, 86.93, 87.93, 88.47, 88.73, 89.27, 89.4 ,
#        89.53, 89.67, 89.67, 89.73, 90.2 , 90.27, 90.33, 90.73, 91.33,
#        92.  ])
